# %% [markdown]
# Importing The Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# Reading and Explore The Data

# %%
df = pd.read_csv('airline_passenger_satisfaction.csv')
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.sample(10) #--> gives us better view as it display a random df
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 8779      8780    Male   57     Returning       Business      Business
# 57715    57716  Female   43    First-time       Business      Business
# 79275    79276  Female   42     Returning       Personal       Economy
# 56107    56108  Female   12     Returning       Personal       Economy
# 6610      6611    Male   27    First-time       Business      Business
# 100968  100969  Female   47     Returning       Personal       Economy
# 97433    97434  Female   29     Returning       Business  Economy Plus
# 105424  105425  Female   38     Returning       Business      Business
# 66536    66537    Male   47     Returning       Personal       Economy
# 88394    88395  Female   22    First-time       Business      Business
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 8779               2673               17           27.0
# 57715               989                4            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
df = df.rename(columns = {"Flight Distance": "Flight_Distance", "Departure Delay": "Departure_Delay_in_Minutes", 'Arrival Delay': 'Arrival_Delay_in_Minutes'})

# %%
df.isna().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight_Distance                             0
# Departure_Delay_in_Minutes                  0
# Arrival_Delay_in_Minutes                  393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
df.duplicated().any()
print(df.columns)
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight_Distance', 'Departure_Delay_in_Minutes',
#        'Arrival_Delay_in_Minutes', 'Departure and Arrival Time Convenience',
#        'Ease of Online Booking', 'Check-in Service', 'Online Boarding',
#        'Gate Location', 'On-board Service', 'Seat Comfort', 'Leg Room Service',
#        'Cleanliness', 'Food and Drink', 'In-flight Service',
#        'In-flight Wifi Service', 'In-flight Entertainment', 'Baggage Handling',
#        'Satisfaction'],
#       dtype='object')

# %%
numircal_cols = ['ID','Age','Flight_Distance','Departure_Delay_in_Minutes','Arrival_Delay_in_Minutes']
vars_categorical = ['Gender', 'Customer Type', 'Ease of Online Booking', 'Check-in Service', 'Online Boarding',
       'Gate Location', 'On-board Service', 'Seat Comfort', 'Leg Room Service',
       'Cleanliness', 'Food and Drink', 'In-flight Service',
       'In-flight Wifi Service', 'In-flight Entertainment', 'Baggage Handling',
       'Satisfaction']

# %% [markdown]
# Getting summary statistics on the data

# %%
stats=df[numircal_cols].describe().T.rename_axis("Col_Name").reset_index()
stats
# Out:
#                      Col_Name     count          mean           std   min  \
# 0                          ID  129880.0  64940.500000  37493.270818   1.0
# 1                         Age  129880.0     39.427957     15.119360   7.0
# 2             Flight_Distance  129880.0   1190.316392    997.452477  31.0
# 3  Departure_Delay_in_Minutes  129880.0     14.713713     38.071126   0.0
# 4    Arrival_Delay_in_Minutes  129487.0     15.091129     38.465650   0.0
#
#         25%      50%       75%       max
# 0  32470.75  64940.5  97410.25  129880.0
# 1     27.00     40.0     51.00      85.0
# 2    414.00    844.0   1744.00    4983.0
# 3      0.00      0.0     12.00    1592.0
# 4      0.00      0.0     13.00    1584.0

# %% [markdown]
# Checking For Outliers

# %%
for col in numircal_cols:
    plt.figure(figsize = (10,2))
    sns.boxplot(data=df,x=col)

# %% [markdown]
# There Is Outliers (Flight Distance,Arrival Delay,Departure Delay)

# %%
df = df.dropna()
df.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# Visualization

# %%
x=df["Satisfaction"].value_counts()

# %%
insights=round(df['Satisfaction'].value_counts(normalize=True)*100,2)
plt.pie(insights.values,labels=insights.index,autopct='%1.1f%%',wedgeprops={'edgecolor':'black'},shadow=True,startangle=90)
plt.title("Distribution of Satisfaction for Airline Passengers")
plt.show()

# %% [markdown]
# Most of them Not Satisfied

# %% [markdown]
# (Gender,Customer,Type)

# %%
cols=['Gender','Customer Type','Type of Travel']
colors = sns.color_palette('pastel')[0:5]
for col in cols:
    x=round(df[col].value_counts(normalize=True)*100,2)
    plt.pie(x.values,labels=x.index,autopct='%1.1f%%',wedgeprops={'edgecolor':'black'},shadow=True,startangle=90,colors=colors)
    plt.title('Distribution for Passengers that has ' + col , weight = 'bold')
    plt.show()

# %% [markdown]
# Female Passangers are More Than Male
# Most of The passangers Are Bussiness Class And Not their First Time

# %% [markdown]
# Getting The relation Between Satisfaction And Numircal Values

# %%
for col in numircal_cols:
    sns.barplot(x = 'Satisfaction', y = col, data = df, errorbar=None)
    plt.title('Relation between Passenger_Satisfaction and ' + col)
    plt.show()

# %% [markdown]
# Relation Between Categorical and Satisfication

# %%
Cat_cols=[n for n in vars_categorical if n!="Satisfaction"]
for cols in Cat_cols:
    
    
    sns.countplot(data = df, 
                  x = 'Satisfaction', 
                  hue = cols)
    
    plt.title('Distribution for Passenger Satisfaction for has ' + cols)
    plt.show()
